# %% [markdown]
# <a href="https://colab.research.google.com/github/JaspreetMaan14/Mini-Project-09-EDA/blob/main/Mini_Project_09_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Exploratory Data Analysis (EDA)**
#
# ---

# %% [markdown]
# ## 1. Importing the required libraries for EDA

# %% [markdown]
# Below are the libraries that are used in order to perform EDA (Exploratory data analysis) in this tutorial.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
#%matplotlib inline
#sns.set(color_codes=True)

# %% [markdown]
# ## 2. Loading the data into the data frame.

# %%
import warnings
warnings.filterwarnings(action='ignore')

# %%
#Read the data from CSV file
df = pd.read_csv('/content/wdbc.data')
df.head()
# Out:
#      842302  M  17.99  10.38   122.8    1001   0.1184   0.2776  0.3001  \
# 0    842517  M  20.57  17.77  132.90  1326.0  0.08474  0.07864  0.0869
# 1  84300903  M  19.69  21.25  130.00  1203.0  0.10960  0.15990  0.1974
# 2  84348301  M  11.42  20.38   77.58   386.1  0.14250  0.28390  0.2414
# 3  84358402  M  20.29  14.34  135.10  1297.0  0.10030  0.13280  0.1980
# 4    843786  M  12.45  15.70   82.57   477.1  0.12780  0.17000  0.1578
#
#     0.1471  ...  25.38  17.33   184.6    2019  0.1622  0.6656  0.7119  0.2654  \
# 0  0.07017  ...  24.99  23.41  158.80  1956.0  0.1238  0.1866  0.2416  0.1860
# 1  0.12790  ...  23.57  25.53  152.50  1709.0  0.1444  0.4245  0.4504  0.2430
# 2  0.10520  ...  14.91  26.50   98.87   567.7  0.2098  0.8663  0.6869  0.2575
# 3  0.10430  ...  22.54  16.67  152.20  1575.0  0.1374  0.2050  0.4000  0.1625
# 4  0.08089  ...  15.47  23.75  103.40   741.6  0.1791  0.5249  0.5355  0.1741
#
#    0.4601   0.1189
# 0  0.2750  0.08902
# 1  0.3613  0.08758
# ...

# %% [markdown]
# ## 3. Renaming the columns

# %%
df = df.rename(columns={"842302": "ID", "M": "Diagnosis", "17.99": "radius1", "10.38": "texture1","122.8": "perimeter1", "1001": "area1", "0.1184": "smoothness1","0.2776": "compactness1" })
df.head(5)
# Out:
#          ID Diagnosis  radius1  texture1  perimeter1  area 1  smoothness1  \
# 0    842517         M    20.57     17.77      132.90  1326.0      0.08474
# 1  84300903         M    19.69     21.25      130.00  1203.0      0.10960
# 2  84348301         M    11.42     20.38       77.58   386.1      0.14250
# 3  84358402         M    20.29     14.34      135.10  1297.0      0.10030
# 4    843786         M    12.45     15.70       82.57   477.1      0.12780
#
#    compactness1  0.3001   0.1471  ...  25.38  17.33   184.6    2019  0.1622  \
# 0       0.07864  0.0869  0.07017  ...  24.99  23.41  158.80  1956.0  0.1238
# 1       0.15990  0.1974  0.12790  ...  23.57  25.53  152.50  1709.0  0.1444
# 2       0.28390  0.2414  0.10520  ...  14.91  26.50   98.87   567.7  0.2098
# 3       0.13280  0.1980  0.10430  ...  22.54  16.67  152.20  1575.0  0.1374
# 4       0.17000  0.1578  0.08089  ...  15.47  23.75  103.40   741.6  0.1791
#
#    0.6656  0.7119  0.2654  0.4601   0.1189
# ...

# %%
df.shape
# Out:
# (568, 32)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 568 entries, 0 to 567
# Data columns (total 32 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ID            568 non-null    int64
#  1   Diagnosis     568 non-null    object
#  2   radius1       568 non-null    float64
#  3   texture1      568 non-null    float64
#  4   perimeter1    568 non-null    float64
#  5   area 1        568 non-null    float64
#  6   smoothness1   568 non-null    float64
#  7   compactness1  568 non-null    float64
#  8   0.3001        568 non-null    float64
#  9   0.1471        568 non-null    float64
#  10  0.2419        568 non-null    float64
#  11  0.07871       568 non-null    float64
#  12  1.095         568 non-null    float64
#  13  0.9053        568 non-null    float64
#  14  8.589         568 non-null    float64
#  15  153.4         568 non-null    float64
#  16  0.006399      568 non-null    float64
# ...

# %% [markdown]
# ## 4. Checking the types of data and any null values

# %%
df.isnull().sum()
# Out:
# ID              0
# Diagnosis       0
# radius1         0
# texture1        0
# perimeter1      0
# area 1          0
# smoothness1     0
# compactness1    0
# 0.3001          0
# 0.1471          0
# 0.2419          0
# 0.07871         0
# 1.095           0
# 0.9053          0
# 8.589           0
# 153.4           0
# 0.006399        0
# 0.04904         0
# 0.05373         0
# 0.01587         0
# 0.03003         0
# 0.006193        0
# 25.38           0
# 17.33           0
# 184.6           0
# 2019            0
# 0.1622          0
# 0.6656          0
# 0.7119          0
# 0.2654          0
# 0.4601          0
# 0.1189          0
# dtype: int64

# %%
df.dtypes
# Out:
# ID                int64
# Diagnosis        object
# radius1         float64
# texture1        float64
# perimeter1      float64
# area 1          float64
# smoothness1     float64
# compactness1    float64
# 0.3001          float64
# 0.1471          float64
# 0.2419          float64
# 0.07871         float64
# 1.095           float64
# 0.9053          float64
# 8.589           float64
# 153.4           float64
# 0.006399        float64
# 0.04904         float64
# 0.05373         float64
# 0.01587         float64
# 0.03003         float64
# 0.006193        float64
# 25.38           float64
# 17.33           float64
# 184.6           float64
# 2019            float64
# 0.1622          float64
# 0.6656          float64
# 0.7119          float64
# 0.2654          float64
# 0.4601          float64
# 0.1189          float64
# dtype: object

# %% [markdown]
# ---

# %% [markdown]
# ## 5. Dropping irrelevant columns

# %%
df.columns
# Out:
# Index(['ID', 'Diagnosis', 'radius1', 'texture1', 'perimeter1', 'area 1',
#        'smoothness1', 'compactness1', '0.3001', '0.1471', '0.2419', '0.07871',
#        '1.095', '0.9053', '8.589', '153.4', '0.006399', '0.04904', '0.05373',
#        '0.01587', '0.03003', '0.006193', '25.38', '17.33', '184.6', '2019',
#        '0.1622', '0.6656', '0.7119', '0.2654', '0.4601', '0.1189'],
#       dtype='object')

# %%
# Dropping unwanted columns
columns_to_drop = ['0.3001', '0.1471', '0.2419', '0.07871',
       '1.095', '0.9053', '8.589', '153.4', '0.006399', '0.04904', '0.05373',
       '0.01587', '0.03003', '0.006193', '25.38', '17.33', '184.6', '2019',
       '0.1622', '0.6656', '0.7119', '0.2654', '0.4601']
df.drop(columns=columns_to_drop, inplace=True)

# %%
df.head(5)
# Out:
#          ID Diagnosis  radius1  texture1  perimeter1  area 1  smoothness1  \
# 0    842517         M    20.57     17.77      132.90  1326.0      0.08474
# 1  84300903         M    19.69     21.25      130.00  1203.0      0.10960
# 2  84348301         M    11.42     20.38       77.58   386.1      0.14250
# 3  84358402         M    20.29     14.34      135.10  1297.0      0.10030
# 4    843786         M    12.45     15.70       82.57   477.1      0.12780
#
#    compactness1
# 0       0.07864
# 1       0.15990
# 2       0.28390
# 3       0.13280
# 4       0.17000

# %% [markdown]
# ---

# %% [markdown]
# ## 6. Dropping the duplicate rows

# %%
df.shape
# Out:
# (568, 8)

# %%
duplicate_rows_df = df[df.duplicated()]
print("number of duplicate rows: ", duplicate_rows_df.shape)
# Out:
# number of duplicate rows:  (0, 8)

# %%
df.count()      # Used to count the number of rows
# Out:
# ID              568
# Diagnosis       568
# radius1         568
# texture1        568
# perimeter1      568
# area 1          568
# smoothness1     568
# compactness1    568
# dtype: int64

# %%
df = df.drop_duplicates()
df.head()
# Out:
#          ID Diagnosis  radius1  texture1  perimeter1  area 1  smoothness1  \
# 0    842517         M    20.57     17.77      132.90  1326.0      0.08474
# 1  84300903         M    19.69     21.25      130.00  1203.0      0.10960
# 2  84348301         M    11.42     20.38       77.58   386.1      0.14250
# 3  84358402         M    20.29     14.34      135.10  1297.0      0.10030
# 4    843786         M    12.45     15.70       82.57   477.1      0.12780
#
#    compactness1
# 0       0.07864
# 1       0.15990
# 2       0.28390
# 3       0.13280
# 4       0.17000

# %%
df.count()
# Out:
# ID              568
# Diagnosis       568
# radius1         568
# texture1        568
# perimeter1      568
# area 1          568
# smoothness1     568
# compactness1    568
# dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# ## 7. Dropping the missing or null values.

# %%
print(df.isnull().sum())
# Out:
# ID              0
# Diagnosis       0
# radius1         0
# texture1        0
# perimeter1      0
# area 1          0
# smoothness1     0
# compactness1    0
# dtype: int64

# %%
df = df.dropna()    # Dropping the missing values.
df.count()
# Out:
# ID              568
# Diagnosis       568
# radius1         568
# texture1        568
# perimeter1      568
# area 1          568
# smoothness1     568
# compactness1    568
# dtype: int64

# %%
print(df.isnull().sum())   # After dropping the values
# Out:
# ID              0
# Diagnosis       0
# radius1         0
# texture1        0
# perimeter1      0
# area 1          0
# smoothness1     0
# compactness1    0
# dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# ## 8. Detecting Outliers

# %% [markdown]
# ![1_0MPDTLn8KoLApoFvI0P2vQ (1).png](data:image/png;base64,...)

# %%
sns.boxplot(x=df['texture1'])
# Out:
# <Axes: xlabel='texture1'>

# %%
sns.boxplot(x=df['ID'])
# Out:
# <Axes: xlabel='ID'>

# %% [markdown]
# ## 9. Plot different features against one another

# %% [markdown]
# ### Histogram
#
# Histogram refers to the frequency of occurrence of variables in an interval. In this case, there are mainly 10 different types of car manufacturing companies, but it is often important to know who has the most number of cars. To do this histogram is one of the trivial solutions which lets us know the total number of car manufactured by a different company.

# %%
import matplotlib.pyplot as plt

plt.hist(df['area 1'], bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of area_mean')
plt.xlabel('Area Mean')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['texture1'])
# Out:
# <Axes: xlabel='texture1', ylabel='Count'>

# %% [markdown]
# ### Scatterplot
#
# We generally use scatter plots to find the correlation between two variables. Here the scatter plots are plotted between Horsepower and Price and we can see the plot below. With the plot given below, we can easily draw a trend line. These features provide a good scattering of points.

# %%
sns.scatterplot(x='perimeter1', y='area 1', hue='Diagnosis', data=df)
plt.title('perimeter_mean vs area_mean')
plt.xlabel('perimeter_mean')
plt.ylabel('area_mean')
plt.legend(title='Diagnosis')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.lineplot(x=df['perimeter1'],y=df['area 1'])
# Out:
# <Axes: xlabel='perimeter1', ylabel='area 1'>

# %% [markdown]
# ### Heat Maps
#
# Heat Maps is a type of plot which is necessary when we need to find the dependent variables. One of the best way to find the relationship between the features can be done using heat maps. In the below heat map we know that the price feature depends mainly on the Engine Size, Horsepower, and Cylinders.

# %%
plt.figure(figsize=(10,5))
c= df.corr(numeric_only=True)
sns.heatmap(c,annot=True)
# Out:
# <Axes: >
